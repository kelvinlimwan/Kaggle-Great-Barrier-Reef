# %% [markdown]
# <a href="https://colab.research.google.com/github/kelvinlimwan/Kaggle-Great-Barrier-Reef/blob/main/Starfish_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import kaggle.json from C:\Users\kelvi\.kaggle
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-871fddc5-5f65-4bfc-aa99-09dc84a4993c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-871fddc5-5f65-4bfc-aa99-09dc84a4993c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"kelvinlim","key":"2cb408e91585800bd288bf0b95c68c73"}'}

# %%
# !pip install --upgrade --force-reinstall --no-deps kaggle

# !mkdir ~/.kaggle

# !cp kaggle.json ~/.kaggle/

# !chmod 600 ~/.kaggle/kaggle.json

# # returns list if commands above ran
# !kaggle datasets list

# %%
# !kaggle competitions download tensorflow-great-barrier-reef -p '/content/drive/MyDrive/Colab Notebooks/Kaggle Great Barrier Reef'
# Out:
# ...
# 100% 14.2G/14.2G [02:49<00:00, 95.0MB/s]
# 100% 14.2G/14.2G [02:49<00:00, 89.6MB/s]

# %%
# !unzip '/content/drive/MyDrive/Colab Notebooks/Kaggle Great Barrier Reef/tensorflow-great-barrier-reef.zip' -d '/content/drive/MyDrive/Colab Notebooks/Kaggle Great Barrier Reef/tensorflow-great-barrier-reef'

# %%
# !cp -r '/content/drive/MyDrive/Colab Notebooks/Kaggle Great Barrier Reef/tensorflow-great-barrier-reef' ./

# %%
from PIL import Image
import matplotlib.pyplot as plt
import os

image_names = os.listdir('/content/tensorflow-great-barrier-reef/train_images/video_0/')

for image_name in image_names[:10]:
  image_path = os.path.join('/content/tensorflow-great-barrier-reef/train_images/video_0/', image_name)
  print(image_path)
  plt.imshow(Image.open(image_path))
  plt.show()
# Out:
# /content/tensorflow-great-barrier-reef/train_images/video_0/5911.jpg
# /content/tensorflow-great-barrier-reef/train_images/video_0/1158.jpg
# /content/tensorflow-great-barrier-reef/train_images/video_0/8129.jpg
# /content/tensorflow-great-barrier-reef/train_images/video_0/2087.jpg
# /content/tensorflow-great-barrier-reef/train_images/video_0/4095.jpg
# /content/tensorflow-great-barrier-reef/train_images/video_0/12269.jpg
# /content/tensorflow-great-barrier-reef/train_images/video_0/11753.jpg
# /content/tensorflow-great-barrier-reef/train_images/video_0/8434.jpg
# /content/tensorflow-great-barrier-reef/train_images/video_0/934.jpg
# /content/tensorflow-great-barrier-reef/train_images/video_0/4157.jpg
